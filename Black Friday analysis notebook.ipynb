# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("BlackFriday.csv")

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.shape
# Out:
# (537577, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  5.375770e+05  537577.00000   537577.000000       537577.000000
# mean   1.002992e+06       8.08271        0.408797            5.295546
# std    1.714393e+03       6.52412        0.491612            3.750701
# min    1.000001e+06       0.00000        0.000000            1.000000
# 25%    1.001495e+06       2.00000        0.000000            1.000000
# 50%    1.003031e+06       7.00000        0.000000            5.000000
# 75%    1.004417e+06      14.00000        1.000000            8.000000
# max    1.006040e+06      20.00000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       370591.000000       164278.000000  537577.000000
# mean             9.842144           12.669840    9333.859853
# std              5.087259            4.124341    4981.022133
# min              2.000000            3.000000     185.000000
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
df.drop(["Product_Category_2","Product_Category_3"], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (537577, 10)

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %%
df.sample(15)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 349465  1005824  P00186642      M  18-25          12             B
# 429602  1000136  P00042842      M  18-25           2             B
# 226919  1004964  P00344542      M  36-45           0             A
# 343463  1004855  P00112142      M  26-35          12             B
# 240116  1001060  P00338442      M  18-25          10             C
# 413284  1003621  P00183142      M  18-25           4             B
# 250175  1002575  P00250342      M  36-45           7             C
# 72182   1005091  P00024042      M  26-35          17             B
# 228290  1005178  P00211142      M  51-55           0             C
# 503604  1005576  P00113142      M  26-35           4             C
# 407914  1002820  P00263542      F  36-45           0             A
# 483612  1002484  P00289942      M  46-50           5             B
# 131653  1002203  P00157542      M  46-50          12             B
# ...

# %%
df["User_ID"].nunique()
# Out:
# 5891

# %%
df["Product_ID"].nunique()
# Out:
# 3623

# %%
df["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df["Occupation"].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df["City_Category"].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df["Stay_In_Current_City_Years"].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df["Marital_Status"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df["Product_Category_1"].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
df["Purchase"].sum()
# Out:
# 5017668378

# %%
for column in df.columns:
    
    print(column, ":", df[column].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Purchase : 17959

# %% [markdown]
# ## Gender Analysis

# %%
df_m = df[df["Gender"]== "M"]

# %%
df_m.shape
# Out:
# (405380, 10)

# %%
df.groupby("Gender").size().plot(kind = "pie",
                                autopct = "%.2f",
                                title = "Gender Ratio")
# Out:
# <Axes: title={'center': 'Gender Ratio'}>

# %%
df.groupby("Gender").sum()["Purchase"].plot(kind = "pie",
                                           autopct = "%.2f",
                                           title = "Gender spending")
# Out:
# <Axes: title={'center': 'Gender spending'}, ylabel='Purchase'>

# %%
df.groupby('Gender').mean(numeric_only=True)['Purchase'].plot(kind = "pie",
                                                             autopct = "%.2f",
                                                             title = "Gender Average Spending")
# Out:
# <Axes: title={'center': 'Gender Average Spending'}, ylabel='Purchase'>

# %% [markdown]
# ## Age and Maritial analysis

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.groupby("Age").size()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
df.groupby("Age").size().plot(kind = "bar")
# Out:
# <Axes: xlabel='Age'>

# %%
for i in df["Age"].unique():
    print(i)
# Out:
# 0-17
# 55+
# 26-35
# 46-50
# 51-55
# 36-45
# 18-25

# %%
lst=[]
for i in df["Age"].unique():
    lst.append([i, df[df["Age"]==i]["Product_ID"].nunique()])

df_age = pd.DataFrame(lst, columns = ["Age", "no_of_product"])

# %%
df_age
# Out:
#      Age  no_of_product
# 0   0-17           2300
# 1    55+           2573
# 2  26-35           3419
# 3  46-50           3099
# 4  51-55           2877
# 5  36-45           3318
# 6  18-25           3213

# %%
sns.barplot(x = "Age", y= "no_of_product", data = df_age)
# Out:
# <Axes: xlabel='Age', ylabel='no_of_product'>

# %%
df.groupby("Age").sum()["Purchase"].plot(kind = "bar")
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby("Age").mean(numeric_only=True)["Purchase"].plot(kind = "bar")
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby("Age").mean(numeric_only=True)["Purchase"].plot(kind = "pie",
                                               autopct= "%.2f",
                                               title = "Age Average Spending")
# Out:
# <Axes: title={'center': 'Age Average Spending'}, ylabel='Purchase'>

# %%
df.groupby("Marital_Status").size().plot(kind = "pie",
                                         autopct = "%.2f",
                                         title = "size based on marital status")
# Out:
# <Axes: title={'center': 'size based on marital status'}>

# %% [markdown]
# ## Multi-Column Analysis

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
sns.countplot(x ="Gender", data = df, hue = "Age")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="Age", data = df, hue = "Gender")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = "City_Category", data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x = "City_Category", data = df, hue = "Gender")
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x = "Marital_Status", data = df, hue = "Gender")
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
  sns.barplot(x = "Gender", y = "Purchase", data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='Purchase'>

# %%
sns.countplot(x= "Age", data = df, hue = "City_Category")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x= "City_Category", data = df, hue = "Age")
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby("Age").sum()["Purchase"].plot(kind = "bar")
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby("Age").sum()["Purchase"].plot(kind = "pie",
                                        autopct = "%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
sns.countplot(hue = "City_Category", data = df, x = "Marital_Status")
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
df.groupby("City_Category").sum()["Purchase"].plot(kind = "pie",
                                                  autopct = "%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby("City_Category").mean(numeric_only= True)["Purchase"].plot(kind = "pie",
                                                                     autopct = "%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby("Marital_Status").sum()["Purchase"].plot(kind = "bar")
# Out:
# <Axes: xlabel='Marital_Status'>

# %%
df.groupby("Marital_Status").mean(numeric_only = True)["Purchase"].plot(kind = "pie",
                                                                       autopct = "%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ## Occupation and Product analysis

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
sns.countplot(x = "Stay_In_Current_City_Years", data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby("Stay_In_Current_City_Years").size().sort_values().plot(kind = "bar")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x = "Stay_In_Current_City_Years", data = df, hue = "Gender")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df["Marital_Status"] = df["Marital_Status"].astype(str)

# %%
sns.countplot(x = "Stay_In_Current_City_Years", data= df, hue = "Marital_Status")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Purchase                    537577 non-null  int64
#  10  Martial_Status              537577 non-null  object
# dtypes: int64(5), object(6)
# memory usage: 45.1+ MB

# %%
sns.countplot(x = "Stay_In_Current_City_Years", data = df, hue = "City_Category")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby("Stay_In_Current_City_Years").sum()["Purchase"].plot(kind = "bar")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
df.groupby("Stay_In_Current_City_Years").mean(numeric_only= True)["Purchase"].plot(kind = "bar")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x = "Occupation", data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby("Occupation").sum()["Purchase"].sort_values().plot(kind = "bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation").mean(numeric_only=True)["Purchase"].sort_values().plot(kind = "bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
sns.countplot(x ="Occupation", data = df, hue = "Marital_Status")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x = "Occupation", data = df, hue = "Gender")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x= "Occupation", data = df, hue = "City_Category")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby("Occupation").nunique()["Product_ID"].sort_values().plot(kind = "bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df["Product_Category_1"].nunique()
# Out:
# 18

# %%
sns.countplot(x = "Product_Category_1", data = df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
df.groupby("Product_Category_1").size().sort_values().plot(kind = "bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby("Product_Category_1").sum()["Purchase"].sort_values().plot(kind = "bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby("Product_Category_1").mean(numeric_only=True)["Purchase"].sort_values().plot(kind = "bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df["Product_ID"].nunique()
# Out:
# 3623

# %%
df.groupby("Product_ID").size().nlargest(10).sort_values().plot(kind = "bar")
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby("Product_ID").sum()["Purchase"].nlargest(10).sort_values().plot(kind = "bar")
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby("Product_ID").mean(numeric_only = True)["Purchase"].nlargest(10).sort_values().plot(kind = "bar")
# Out:
# <Axes: xlabel='Product_ID'>

# %%
sns.countplot(x = "Product_Category_1", data = df, hue = "Gender")
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x = "Product_Category_1", data = df, hue = "Marital_Status")
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>
