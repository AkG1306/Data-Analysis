# %%
import pandas as pd
import numpy as np
import matplotlib as mat
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mat.rcParams["figure.figsize"]=(15,6)

# %%
df = pd.read_csv("zomato.csv", encoding = "latin-1")

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# ## In data analysis what all we do
#
# 1. Missing Values
# 2. Explore Numerical variables
# 3. Explore Categorical Variable
# 4. Finding Relation between features

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
sns.heatmap(df.isnull(), cmap = "viridis", yticklabels=False)
# Out:
# <Axes: >

# %%
df_country = pd.read_excel("Country-Code.xlsx")
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
final_df = pd.merge(df,df_country, on = "Country Code", how = "left")

# %%
final_df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
Country_names = final_df["Country"].value_counts().index

# %%
## Pie Chart - Top 3 countries that uses zomato

final_df.groupby("Country").size().nlargest(3).plot(kind = "pie",
                                                   autopct = "%.2f")
# Out:
# <Axes: >

# %% [markdown]
# Observation: Zomato is used in India after that USA and then UK

# %%
ratings = final_df.groupby(["Aggregate rating", "Rating color", "Rating text"]).size().reset_index().rename(columns = {0:"Rating Count"})

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# ## Observation :
#
# 1. When the rating is between 4.5 to 4.9 -------> Excellent
# 2. When the rating is between 4.0 to 4.4 -------> Very Good
# 3. When the rating is between 3.5 to 3.9 -------> Good
# 4. When the rating is between 2.5 to 3.4 -------> Average
# 5. When the rating is between 0.0 to 2.4 -------> Poor

# %%
plt.style.use("Solarize_Light2")
sns.barplot(x = "Aggregate rating", y = "Rating Count", data= ratings)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
plt.style.use('dark_background')

sns.barplot(x = "Aggregate rating", y = "Rating Count",
            data = ratings,
            hue = "Rating text", 
            palette=["white","red","orange","yellow","green","green"])
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
plt.style.use('dark_background')
df.groupby("Aggregate rating").size().plot(kind = "bar")
# Out:
# <Axes: xlabel='Aggregate rating'>

# %% [markdown]
# ## Observation:
# 1. Not rated count is very high
# 2. Maximum number of rating is between 2.5 to 3.4 ------> Average

# %% [markdown]
# ### Find the country names that has given 0 rating

# %%
final_df[final_df["Aggregate rating"]==0]["Country"].value_counts().reset_index()
# Out:
#           Country  count
# 0           India   2139
# 1          Brazil      5
# 2   United States      3
# 3  United Kingdom      1

# %% [markdown]
# ## Observation:
# 1. Maximum number of 0 rating restraunts are in India

# %% [markdown]
# ## find which currency is used by which country

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
for country in final_df["Country"].unique():
    currency = final_df[final_df["Country"]==country]["Currency"].unique()
    print(country + " : "+ currency)
# Out:
# ['Phillipines : Botswana Pula(P)']
# ['Brazil : Brazilian Real(R$)']
# ['United States : Dollar($)']
# ['Australia : Dollar($)']
# ['Canada : Dollar($)']
# ['Singapore : Dollar($)']
# ['UAE : Emirati Diram(AED)']
# ['India : Indian Rupees(Rs.)']
# ['Indonesia : Indonesian Rupiah(IDR)']
# ['New Zealand : NewZealand($)']
# ['United Kingdom : Pounds(\x8c£)']
# ['Qatar : Qatari Rial(QR)']
# ['South Africa : Rand(R)']
# ['Sri Lanka : Sri Lankan Rupee(LKR)']
# ['Turkey : Turkish Lira(TL)']

# %%
final_df.groupby(["Country","Currency"]).size().reset_index().rename(columns={0:"countries occurance"})
# Out:
#            Country                Currency  countries occurance
# 0        Australia               Dollar($)                   24
# 1           Brazil      Brazilian Real(R$)                   60
# 2           Canada               Dollar($)                    4
# 3            India      Indian Rupees(Rs.)                 8652
# 4        Indonesia  Indonesian Rupiah(IDR)                   21
# 5      New Zealand           NewZealand($)                   40
# 6      Phillipines        Botswana Pula(P)                   22
# 7            Qatar         Qatari Rial(QR)                   20
# 8        Singapore               Dollar($)                   20
# 9     South Africa                 Rand(R)                   60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)                   20
# 11          Turkey        Turkish Lira(TL)                   34
# 12             UAE      Emirati Diram(AED)                   60
# 13  United Kingdom              Pounds(£)                   80
# ...

# %% [markdown]
# ## Which Country has Online Delivery option

# %%
final_df.groupby(["Country","Has Online delivery"]).size().reset_index()
# Out:
#            Country Has Online delivery     0
# 0        Australia                  No    24
# 1           Brazil                  No    60
# 2           Canada                  No     4
# 3            India                  No  6229
# 4            India                 Yes  2423
# 5        Indonesia                  No    21
# 6      New Zealand                  No    40
# 7      Phillipines                  No    22
# 8            Qatar                  No    20
# 9        Singapore                  No    20
# 10    South Africa                  No    60
# 11       Sri Lanka                  No    20
# 12          Turkey                  No    34
# 13             UAE                  No    32
# 14             UAE                 Yes    28
# 15  United Kingdom                  No    80
# 16   United States                  No   434

# %%
final_df[final_df["Has Online delivery"]=="Yes"]["Country"].value_counts().reset_index()
# Out:
#   Country  count
# 0   India   2423
# 1     UAE     28

# %% [markdown]
# ## Observation:
# 1. Restaurants in only India and UAE offers Online Delivery

# %% [markdown]
# ## Create a pie chart for city distribution

# %%
final_df.groupby("City").size().nlargest(5).plot(kind = "pie",
                                                autopct = "%.2f")
# Out:
# <Axes: >

# %%
city_counts = final_df.City.value_counts().values
city_labels = final_df.City.value_counts().index

plt.pie(city_counts[:5],labels = city_labels[:5],
       autopct = "%.2f")
# Out:
# ([<matplotlib.patches.Wedge at 0x2bab566e550>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')],
#  [Text(-0.3352010631374145, 0.497634652402289, '68.87'),
#   Text(0.0340186500653484, -0.5990348332507311, '14.07'),
#   Text(0.47940246685229276, -0.36079533641101336, '13.59'),
#   Text(0.5957573682667329, -0.07122610585941394, '3.16'),
#   Text(0.5999706981848791, -0.005929698099289049, '0.31')])

# %%
# Out:
# City
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: count, Length: 141, dtype: int64

# %% [markdown]
# ## Find the top 10 Cuisines

# %%
cuisines = final_df.groupby("Cuisines").size().nlargest(10).reset_index().rename(columns={0:"count"})
cuisines
# Out:
#                          Cuisines  count
# 0                    North Indian    936
# 1           North Indian, Chinese    511
# 2                         Chinese    354
# 3                       Fast Food    354
# 4           North Indian, Mughlai    334
# 5                            Cafe    299
# 6                          Bakery    218
# 7  North Indian, Mughlai, Chinese    197
# 8                Bakery, Desserts    170
# 9                     Street Food    149

# %%
sns.barplot(x = "Cuisines", y = "count", data = cuisines)
# Out:
# <Axes: xlabel='Cuisines', ylabel='count'>

# %%
final_df.groupby("Cuisines").size().nlargest(10).plot(kind = "bar")
# Out:
# <Axes: xlabel='Cuisines'>
